# %% [markdown]
# <a href="https://colab.research.google.com/github/dthompson2003/Digital-Imaging-Final/blob/main/Model/Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Model Stuff in here")
